# %%
https://docs.databricks.com/aws/en/getting-started/create-table

# %%
# %sql
use catalog workspace

# %%
# %sql
create table if not exists default.department
(
  deptcode int,
  deptname string,
  location string
);

# %%
# %sql
insert into workspace.default.department values
(10, 'finance', 'edinburgh'),
(20, 'software', 'paddington')

# %%
# %sql
grant select on workspace.default.department to `all-users`;
