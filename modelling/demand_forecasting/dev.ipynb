# %%
# !pip install -r requirements.txt
# Out:
# Collecting xgboost>=1.7.0 (from -r requirements.txt (line 4))
#   Downloading xgboost-3.1.1-py3-none-macosx_10_15_x86_64.whl.metadata (2.1 kB)
# Collecting scikit-learn>=1.3.0 (from -r requirements.txt (line 5))
#   Downloading scikit_learn-1.7.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=2.0.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: numpy>=1.24.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.26.0)
# Collecting prophet>=1.1.0 (from -r requirements.txt (line 10))
#   Downloading prophet-1.2.1-py3-none-macosx_10_11_x86_64.whl.metadata (3.5 kB)
# Collecting statsmodels>=0.14.0 (from -r requirements.txt (line 11))
#   Downloading statsmodels-0.14.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.5 kB)
# Collecting mlflow>=2.5.0 (from -r requirements.txt (line 14))
#   Downloading mlflow-3.5.0-py3-none-any.whl.metadata (30 kB)
# Collecting matplotlib>=3.7.0 (from -r requirements.txt (line 17))
#   Downloading matplotlib-3.10.7-cp311-cp311-macosx_10_12_x86_64.whl.metadata (11 kB)
# Collecting seaborn>=0.12.0 (from -r requirements.txt (line 18))
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: loguru>=0.7.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (0.7.2)
# Collecting pyspark>=3.4.0 (from -r requirements.txt (line 24))
#   Downloading pyspark-4.0.1.tar.gz (434.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.2/434.2 MB 7.7 MB/s  0:00:520:00:0100:02
#   Preparing metadata (setup.py) ... done
# Collecting scipy (from xgboost>=1.7.0->-r requirements.txt (line 4))
#   Downloading scipy-1.16.2-cp311-cp311-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.3.0->-r requirements.txt (line 5))
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.3.0->-r requirements.txt (line 5))
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from pandas>=2.0.0->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from pandas>=2.0.0->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from pandas>=2.0.0->-r requirements.txt (line 6)) (2025.2)
# Collecting cmdstanpy>=1.0.4 (from prophet>=1.1.0->-r requirements.txt (line 10))
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting holidays<1,>=0.25 (from prophet>=1.1.0->-r requirements.txt (line 10))
#   Downloading holidays-0.83-py3-none-any.whl.metadata (50 kB)
# Collecting tqdm>=4.36.1 (from prophet>=1.1.0->-r requirements.txt (line 10))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting importlib_resources (from prophet>=1.1.0->-r requirements.txt (line 10))
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting patsy>=0.5.6 (from statsmodels>=0.14.0->-r requirements.txt (line 11))
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from statsmodels>=0.14.0->-r requirements.txt (line 11)) (25.0)
# Collecting mlflow-skinny==3.5.0 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading mlflow_skinny-3.5.0-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.5.0 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading mlflow_tracing-3.5.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading alembic-1.17.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting cryptography<47,>=43.0.0 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting fastmcp<3,>=2.0.0 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading fastmcp-2.12.5-py3-none-any.whl.metadata (19 kB)
# Collecting graphene<4 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mlflow>=2.5.0->-r requirements.txt (line 14)) (21.0.0)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading sqlalchemy-2.0.44-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (8.3.0)
# Collecting cloudpickle<4 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.69.0)
# Collecting fastapi<1 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading fastapi-0.119.1-py3-none-any.whl.metadata (28 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (6.33.0)
# Collecting pydantic<3,>=1.10.8 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (2.32.5)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (4.15.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.7.0->-r requirements.txt (line 17))
#   Downloading contourpy-1.3.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.7.0->-r requirements.txt (line 17))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.7.0->-r requirements.txt (line 17))
#   Downloading fonttools-4.60.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.7.0->-r requirements.txt (line 17))
#   Downloading kiwisolver-1.4.9-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.7.0->-r requirements.txt (line 17))
#   Downloading pillow-12.0.0-cp311-cp311-macosx_10_10_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.7.0->-r requirements.txt (line 17))
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi>=2.0.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from cryptography<47,>=43.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (2.41.1)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (2.5.0)
# Collecting starlette<0.49.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading starlette-0.48.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting authlib>=1.5.2 (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading authlib-1.6.5-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting cyclopts>=3.0.0 (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading cyclopts-4.0.0-py3-none-any.whl.metadata (12 kB)
# Collecting exceptiongroup>=1.2.2 (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: httpx>=0.28.1 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.28.1)
# Collecting mcp<1.17.0,>=1.12.4 (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading mcp-1.16.0-py3-none-any.whl.metadata (80 kB)
# Collecting openapi-core>=0.19.5 (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting openapi-pydantic>=0.5.1 (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading openapi_pydantic-0.5.1-py3-none-any.whl.metadata (10 kB)
# Collecting pyperclip>=1.9.0 (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading pyperclip-1.11.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: rich>=13.9.4 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (13.9.4)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from Flask<4->mlflow>=2.5.0->-r requirements.txt (line 14)) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from Flask<4->mlflow>=2.5.0->-r requirements.txt (line 14)) (3.0.3)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (4.9.1)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: anyio>=4.5 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (4.11.0)
# Collecting httpx-sse>=0.4 (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (4.25.1)
# Collecting pydantic-settings>=2.5.2 (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting python-multipart>=0.0.9 (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting sse-starlette>=1.6.1 (from mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading sse_starlette-3.0.2-py3-none-any.whl.metadata (11 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading pydantic_core-2.41.4-cp311-cp311-macosx_10_12_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.6.1)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading greenlet-3.2.4-cp311-cp311-macosx_11_0_universal2.whl.metadata (4.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from anyio>=4.5->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from uvicorn<1->mlflow-skinny==3.5.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.16.0)
# Collecting py4j==0.10.9.9 (from pyspark>=3.4.0->-r requirements.txt (line 24))
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pycparser in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (2.23)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet>=1.1.0->-r requirements.txt (line 10))
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: attrs>=23.1.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (25.4.0)
# Collecting docstring-parser<4.0,>=0.15 (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting rich-rst<2.0.0,>=1.3.1 (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading rich_rst-1.3.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting docutils (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading docutils-0.22.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: httpcore==1.* in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.27.1)
# Collecting isodate (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.20.0->mcp<1.17.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Using cached referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: rfc3339-validator in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.1.4)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading lazy_object_proxy-1.12.0.tar.gz (43 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting email-validator>=2.0.0 (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14))
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.5.0->-r requirements.txt (line 14)) (0.1.2)
# Downloading xgboost-3.1.1-py3-none-macosx_10_15_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 4.4 MB/s  0:00:00 eta 0:00:01m
# Downloading scikit_learn-1.7.2-cp311-cp311-macosx_10_9_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 13.4 MB/s  0:00:00 eta 0:00:01
# Downloading prophet-1.2.1-py3-none-macosx_10_11_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 2.7 MB/s  0:00:04m0:00:0100:01
# Downloading holidays-0.83-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.1 MB/s  0:00:00
# Downloading statsmodels-0.14.5-cp311-cp311-macosx_10_9_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 3.7 MB/s  0:00:02eta 0:00:01m
# Downloading mlflow-3.5.0-py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 9.9 MB/s  0:00:00m eta 0:00:01
# Downloading mlflow_skinny-3.5.0-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.0 MB/s  0:00:00 eta 0:00:01
# Downloading mlflow_tracing-3.5.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.9 MB/s  0:00:00
# Downloading matplotlib-3.10.7-cp311-cp311-macosx_10_12_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 10.3 MB/s  0:00:00 eta 0:00:01
# Downloading alembic-1.17.0-py3-none-any.whl (247 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 11.2 MB/s  0:00:00m0:00:0100:01
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.119.1-py3-none-any.whl (108 kB)
# Downloading fastmcp-2.12.5-py3-none-any.whl (329 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Using cached gitpython-3.1.45-py3-none-any.whl (208 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading mcp-1.16.0-py3-none-any.whl (167 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
# Downloading pydantic_core-2.41.4-cp311-cp311-macosx_10_12_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.9 MB/s  0:00:00 eta 0:00:01m
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading scipy-1.16.2-cp311-cp311-macosx_14_0_x86_64.whl (23.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 3.1 MB/s  0:00:07m0:00:0100:01
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sqlalchemy-2.0.44-cp311-cp311-macosx_10_9_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.8 MB/s  0:00:00
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.48.0-py3-none-any.whl (73 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading authlib-1.6.5-py2.py3-none-any.whl (243 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Downloading contourpy-1.3.3-cp311-cp311-macosx_10_9_x86_64.whl (288 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading cyclopts-4.0.0-py3-none-any.whl (178 kB)
# Using cached docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading rich_rst-1.3.2-py3-none-any.whl (12 kB)
# Using cached exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Downloading fonttools-4.60.1-cp311-cp311-macosx_10_9_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.5 MB/s  0:00:00 eta 0:00:01
# Downloading greenlet-3.2.4-cp311-cp311-macosx_11_0_universal2.whl (272 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading kiwisolver-1.4.9-cp311-cp311-macosx_10_9_x86_64.whl (66 kB)
# Downloading openapi_core-0.19.5-py3-none-any.whl (106 kB)
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
# Downloading openapi_pydantic-0.5.1-py3-none-any.whl (96 kB)
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading pillow-12.0.0-cp311-cp311-macosx_10_10_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 9.4 MB/s  0:00:00m eta 0:00:01
# Downloading pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading pyperclip-1.11.0-py3-none-any.whl (11 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading sse_starlette-3.0.2-py3-none-any.whl (11 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading docutils-0.22.2-py3-none-any.whl (632 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 12.4 MB/s  0:00:00
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Building wheels for collected packages: pyspark, lazy-object-proxy
#   DEPRECATION: Building 'pyspark' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pyspark'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-4.0.1-py2.py3-none-any.whl size=434813860 sha256=5766362aee0e833208eff001c8a0c2bcf4eeb6e1fb4e834331f16431933bc1ad
#   Stored in directory: /Users/samhardyhey/Library/Caches/pip/wheels/76/f8/dc/9195b82b8586561710077d42370ae400e8a023af43052d1fec
#   Building wheel for lazy-object-proxy (pyproject.toml) ... done
#   Created wheel for lazy-object-proxy: filename=lazy_object_proxy-1.12.0-cp311-cp311-macosx_10_15_x86_64.whl size=24518 sha256=f9d392f4f6cfb47244420f01807b98c17e3bcd62eae90e93abb376cda042a852
#   Stored in directory: /Users/samhardyhey/Library/Caches/pip/wheels/70/3c/7a/851b23b02a429de51b9bbf560a9b2afa8a179919d2806d4dce
# Successfully built pyspark lazy-object-proxy
# Installing collected packages: pyperclip, py4j, parse, zipp, werkzeug, uvicorn, typing-inspection, tqdm, threadpoolctl, stanio, sqlparse, smmap, scipy, referencing, python-multipart, python-dotenv, pyspark, pyparsing, pydantic-core, pillow, patsy, pathable, opentelemetry-proto, more-itertools, Mako, lazy-object-proxy, kiwisolver, joblib, itsdangerous, isodate, importlib_resources, httpx-sse, gunicorn, greenlet, graphql-core, fonttools, exceptiongroup, docutils, docstring-parser, dnspython, cycler, contourpy, cloudpickle, blinker, annotated-types, xgboost, starlette, sse-starlette, sqlalchemy, scikit-learn, pydantic, matplotlib, jsonschema-path, importlib_metadata, holidays, graphql-relay, gitdb, Flask, email-validator, docker, cryptography, statsmodels, seaborn, rich-rst, pydantic-settings, opentelemetry-api, openapi-pydantic, graphene, gitpython, Flask-CORS, fastapi, cmdstanpy, authlib, alembic, prophet, opentelemetry-semantic-conventions, openapi-schema-validator, mcp, cyclopts, opentelemetry-sdk, openapi-spec-validator, openapi-core, mlflow-tracing, mlflow-skinny, fastmcp, mlflow
#   Attempting uninstall: py4j
#     Found existing installation: py4j 0.10.9.7
#     Uninstalling py4j-0.10.9.7:
#       Successfully uninstalled py4j-0.10.9.7
#   Attempting uninstall: referencing━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/86 [scipy]ug]
#     Found existing installation: referencing 0.37.0━━━━━━━━━━━ 12/86 [scipy]
#     Uninstalling referencing-0.37.0:━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/86 [scipy]
#       Successfully uninstalled referencing-0.37.0━━━━━━━━━━━━━ 12/86 [scipy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86/86 [mlflow] [mlflow]][mlflow-skinny]]dk]onventions]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-connect 15.1.3 requires py4j==0.10.9.7, but you have py4j 0.10.9.9 which is incompatible.
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.0 annotated-types-0.7.0 authlib-1.6.5 blinker-1.9.0 cloudpickle-3.1.1 cmdstanpy-1.3.0 contourpy-1.3.3 cryptography-46.0.3 cycler-0.12.1 cyclopts-4.0.0 dnspython-2.8.0 docker-7.1.0 docstring-parser-0.17.0 docutils-0.22.2 email-validator-2.3.0 exceptiongroup-1.3.0 fastapi-0.119.1 fastmcp-2.12.5 fonttools-4.60.1 gitdb-4.0.12 gitpython-3.1.45 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 greenlet-3.2.4 gunicorn-23.0.0 holidays-0.83 httpx-sse-0.4.3 importlib_metadata-8.7.0 importlib_resources-6.5.2 isodate-0.7.2 itsdangerous-2.2.0 joblib-1.5.2 jsonschema-path-0.3.4 kiwisolver-1.4.9 lazy-object-proxy-1.12.0 matplotlib-3.10.7 mcp-1.16.0 mlflow-3.5.0 mlflow-skinny-3.5.0 mlflow-tracing-3.5.0 more-itertools-10.8.0 openapi-core-0.19.5 openapi-pydantic-0.5.1 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 parse-1.20.2 pathable-0.4.4 patsy-1.0.2 pillow-12.0.0 prophet-1.2.1 py4j-0.10.9.9 pydantic-2.12.3 pydantic-core-2.41.4 pydantic-settings-2.11.0 pyparsing-3.2.5 pyperclip-1.11.0 pyspark-4.0.1 python-dotenv-1.1.1 python-multipart-0.0.20 referencing-0.36.2 rich-rst-1.3.2 scikit-learn-1.7.2 scipy-1.16.2 seaborn-0.13.2 smmap-5.0.2 sqlalchemy-2.0.44 sqlparse-0.5.3 sse-starlette-3.0.2 stanio-0.5.1 starlette-0.48.0 statsmodels-0.14.5 threadpoolctl-3.6.0 tqdm-4.67.1 typing-inspection-0.4.2 uvicorn-0.38.0 werkzeug-3.1.1 xgboost-3.1.1 zipp-3.23.0

# %%
from statsmodels.tsa.exponential_smoothing import ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose
# Out:
# [autoreload of pyspark.conf failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/conf.py", line 23, in <module>
#     from pyspark.util import is_remote_only
# ImportError: cannot import name 'is_remote_only' from 'pyspark.util' (/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/util.py)
# ]
# [autoreload of pyspark.sql.types failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 415, in update_class
#     update_instances(old, new)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 373, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to DataTypeSingleton object
# ]
# [autoreload of pyspark.sql.column failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _() requires a code object with 2 free vars, not 1
# ]
# [autoreload of pyspark.sql.streaming.listener failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pyspark.sql.streaming failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/streaming/__init__.py", line 21, in <module>
#     from pyspark.sql.streaming.stateful_processor import (  # noqa: F401
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/streaming/stateful_processor.py", line 21, in <module>
#     from pyspark.sql.streaming.stateful_processor_api_client import (
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/streaming/stateful_processor_api_client.py", line 30, in <module>
#     from pyspark.sql.pandas.types import convert_pandas_using_numpy_type
# ImportError: cannot import name 'convert_pandas_using_numpy_type' from 'pyspark.sql.pandas.types' (/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/pandas/types.py)
# ]
# [autoreload of pyspark.sql.pandas.conversion failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: toPandas() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pyspark.sql.dataframe failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: registerTempTable() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pyspark.sql.window failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: partitionBy() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pyspark.sql.connect.proto.common_pb2 failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/common_pb2.py", line 37, in <module>
#     DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Couldn't build proto file into descriptor pool: duplicate file name spark/connect/common.proto
# ]
# [autoreload of pyspark.sql.connect.proto.types_pb2 failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/types_pb2.py", line 37, in <module>
#     DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Couldn't build proto file into descriptor pool: duplicate file name spark/connect/types.proto
# ]
# [autoreload of pyspark.sql.connect.proto.expressions_pb2 failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/expressions_pb2.py", line 42, in <module>
#     DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Couldn't build proto file into descriptor pool: duplicate file name spark/connect/expressions.proto
# ]
# [autoreload of pyspark.sql.connect.proto.relations_pb2 failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/relations_pb2.py", line 45, in <module>
#     DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Couldn't build proto file into descriptor pool: duplicate file name spark/connect/relations.proto
# ]
# [autoreload of pyspark.sql.connect.proto.commands_pb2 failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/commands_pb2.py", line 41, in <module>
#     from pyspark.sql.connect.proto import ml_pb2 as spark_dot_connect_dot_ml__pb2
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/ml_pb2.py", line 42, in <module>
#     DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Couldn't build proto file into descriptor pool: couldn't resolve name '.spark.connect.Fetch'
# ]
# [autoreload of pyspark.sql.connect.proto.base_pb2 failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/base_pb2.py", line 43, in <module>
#     from pyspark.sql.connect.proto import ml_pb2 as spark_dot_connect_dot_ml__pb2
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/ml_pb2.py", line 42, in <module>
#     DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Couldn't build proto file into descriptor pool: couldn't resolve name '.spark.connect.Fetch'
# ]
# [autoreload of pyspark.sql.connect.proto failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/__init__.py", line 26, in <module>
#     from pyspark.sql.connect.proto.ml_pb2 import *
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/proto/ml_pb2.py", line 42, in <module>
#     DESCRIPTOR = _descriptor_pool.Default().AddSerializedFile(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Couldn't build proto file into descriptor pool: couldn't resolve name '.spark.connect.Fetch'
# ]
# [autoreload of pyspark.sql.connect.column failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: wrapped() requires a code object with 2 free vars, not 1
# ]
# [autoreload of pyspark.sql.connect.plan failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/plan.py", line 2650, in <module>
#     class PythonDataSource:
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/plan.py", line 2657, in PythonDataSource
#     def to_plan(self, session: "SparkConnectClient") -> proto.PythonDataSource:
#                                                         ^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pyspark.sql.connect.proto' has no attribute 'PythonDataSource'
# ]
# [autoreload of pyspark.sql.connect.functions.builtin failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: col() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pyspark.sql.connect.dataframe failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/dataframe.py", line 78, in <module>
#     from pyspark.sql.connect.merge import MergeIntoWriter
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/merge.py", line 40, in <module>
#     action_type: proto.MergeAction.ActionType.ValueType,
#                  ^^^^^^^^^^^^^^^^^
# AttributeError: module 'pyspark.sql.connect.proto' has no attribute 'MergeAction'
# ]
# [autoreload of pyspark.sql.connect.client.core failed: Traceback (most recent call last):
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py", line 94, in <module>
#     from pyspark.sql.connect.plan import (
# ImportError: cannot import name 'CommonInlineUserDefinedDataSource' from 'pyspark.sql.connect.plan' (/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/pyspark/sql/connect/plan.py)
# ]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from statsmodels.tsa.exponential_smoothing import ExponentialSmoothing
#       2 from statsmodels.tsa.seasonal import seasonal_decompose
#
# ImportError: cannot import name 'ExponentialSmoothing' from 'statsmodels.tsa.exponential_smoothing' (/Users/samhardyhey/miniconda/envs/databricks-misc/lib/python3.11/site-packages/statsmodels/tsa/exponential_smoothing/__init__.py)
